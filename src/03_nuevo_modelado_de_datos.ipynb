# %% [markdown]
# Librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# En este notebook se reestructura las variables del dataset original para facilitar el análisis posterior. Para ello, se revisa con los doctores el manejo de fechas y dias. Adicionalmente, como los datos originales vienen codificados, se utiliza el codebook para decodificar las categorías. De está forma, se crea una nueva hoja que en vez de los números de las categorías contenga las categorías en texto. Esta nueva hoja se guarda como un nuevo archivo excel para subir al sharepoint que se usará en el Power BI y Power Apps.

# %% [markdown]
# Se carga el codebook para entender las variables.

# %%
df_codebook = pd.read_json('../data/Codebook.json')
df_codebook
# Out:
#                 Variable                                        Descripción  \
# 0     Código anonimizado  código anonimizado para tratamiento de datos d...
# 1           #Paciente_Tx                                 número de paciente
# 2                 Año_Tx                                 año del trasplante
# 3               Fecha_Tx   tiempo transcurrido desde el trasplante hepático
# 4           Etiología_#1   enfermedad que lo llevó a la enfermedad hepática
# ..                   ...                                                ...
# 56              Vivo_Hoy                            define si está vivo hoy
# 57  Fecha_Control/Muerte                            fecha de control/muerte
# 58        SOBREVIDA_DIAS                  sobrevida en días post trasplante
# 59       SOBREVIDA_MESES                 sobrevida en meses post trasplante
# 60        SOBREVIDA_AÑOS                  sobrevida en años post trasplante
#
#      Tipo de Variable                                            Valores
# 0               Texto                                                 {}
# 1   Númerica Discreta                                                 {}
# 2   Númerica Discreta                                                 {}
# 3               Fecha                                                 {}
# 4          Categórica  {'0': 'NINGUNA', '1': 'HCV', '2': 'HBV', '3': ...
# ..                ...                                                ...
# 56         Categórica                             {'0': 'NO', '1': 'SI'}
# 57              Fecha                                                 {}
# 58  Númerica Discreta                                                 {}
# 59  Númerica Continua                                                 {}
# 60  Númerica Continua                                                 {}
#
# [61 rows x 4 columns]

# %% [markdown]
# Se carga la base de datos limpia.

# %%
data = pd.read_excel('../data/Base_infecciones_POPTH_limpia.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557 entries, 0 to 556
# Data columns (total 61 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Código anonimizado                          557 non-null    object
#  1   #Paciente_Tx                                557 non-null    int64
#  2   Año_Tx                                      557 non-null    int64
#  3   Fecha_Tx                                    557 non-null    datetime64[ns]
#  4   Etiología_#1                                557 non-null    int64
#  5   Etiología_#2                                557 non-null    int64
#  6   Edad                                        557 non-null    int64
#  7   Sexo                                        557 non-null    int64
#  8   Child_Pugh_Score_Cat                        158 non-null    object
#  9   Child_Pugh_Score                            152 non-null    float64
#  10  Meld_Score                                  535 non-null    float64
#  11  Diabetes_Mellitus                           547 non-null    float64
#  12  Tabaquismo                                  552 non-null    float64
#  13  Alcoholismo                                 552 non-null    float64
#  14  Hipertensión_Arterial                       430 non-null    float64
#  15  Peso_previo_Cx                              284 non-null    float64
#  16  Talla                                       279 non-null    float64
#  17  IMC                                         275 non-null    float64
#  18  Antecedente_UCI_6_meses_PreOP               551 non-null    float64
#  19  UCI_al_Momento_Tx                           554 non-null    float64
#  20  Tiempo_Isquemia_Fria                        377 non-null    float64
#  21  Tiempo_Isquemia_caliente                    415 non-null    float64
#  22  Tiempo_Cx                                   470 non-null    float64
#  23  Tipo_Reconstrucción_Biliar                  518 non-null    float64
#  24  Infección_Al_Momento_Tx                     557 non-null    int64
#  25  Localización de la infección                124 non-null    float64
#  26  Germen/Microorganismo aislado               78 non-null     float64
#  27  Antibiotico_previo_al_Tx                    557 non-null    int64
#  28  Días_Tratamiento_Antibiótico_Previo_A_Tx#1  557 non-null    int64
#  29  Antibiótico_Profiláctico_VS_Terapéutico     557 non-null    int64
#  30  Antibiótico_1__Tx#1                         557 non-null    int64
#  31  Antibiótico_2_Tx#1                          557 non-null    int64
#  32  Antibiótico_3_Tx#1                          556 non-null    float64
#  33  Antifúngico_Tx#1                            557 non-null    int64
#  34  Tiempo_De_Dosis_Hasta_Tx#1                  306 non-null    float64
#  35  Nutrición_Enteral                           554 non-null    float64
#  36  Días_Nutrición_Enteral                      553 non-null    float64
#  37  Complicaciones_Técnicas                     557 non-null    int64
#  38  Dias_Estancia_Hospitalaria                  557 non-null    int64
#  39  Días_Hospitalización_UCI                    538 non-null    float64
#  40  Días_En_Hospitalización_Piso                553 non-null    float64
#  41  Días_Totales_Intrahospitalarios             452 non-null    float64
#  42  Inmunosupresión_con_Anticuerpos             190 non-null    float64
#  43  Inmunosupresor_1_Postx                      544 non-null    float64
#  44  Inmunosupresor_2_PostTx                     544 non-null    float64
#  45  Inmunosupresor_1_1mesPostTx                 516 non-null    float64
#  46  Inmunosupresor_2_PostTx_1mesPx              516 non-null    float64
#  47  Inmunosupresor_1_6mesesPostx                490 non-null    float64
#  48  Inmunosupresor_2_6mesesPostTx               489 non-null    float64
#  49  Fecha_Egreso_UCI                            128 non-null    datetime64[ns]
#  50  Fecha_Egreso_Hospitalario                   188 non-null    datetime64[ns]
#  51  Requerimiento_de_diálisis                   557 non-null    int64
#  52  Días_En_UCI_POP                             491 non-null    float64
#  53  Trasfusión_GRE_hasta_1m_POP                 557 non-null    int64
#  54  Reintervención_Quirúrgica_hasta_1m_POP      553 non-null    float64
#  55  Retrasplante                                555 non-null    float64
#  56  Vivo_Hoy                                    557 non-null    int64
#  57  Fecha_Control/Muerte                        557 non-null    datetime64[ns]
#  58  SOBREVIDA_DIAS                              557 non-null    int64
#  59  SOBREVIDA_MESES                             557 non-null    float64
#  60  SOBREVIDA_AÑOS                              557 non-null    float64
# dtypes: datetime64[ns](4), float64(36), int64(19), object(2)
# memory usage: 265.6+ KB

# %% [markdown]
# Creamos un dataframe nuevo donde se guardará la estructuración nueva de las variables y la decodificación de las categorías.

# %%
data_new = data.copy()

# %% [markdown]
# # Fechas

# %% [markdown]
# Una ruta típica de un paciente trasplantado es la siguiente:
#
# Ingreso hospital ──(preoperatorio)──► Cirugía Tx ─► UCI ─► Piso (hospitalización común) ─► Alta
#
# Para modelar adecuadamente los días de estancia en cada fase, es necesario contar con las siguientes fechas clave:
# - Fecha_Ingreso_Hospitalario (No existe en el dataset, la añadimos)
# - Fecha_Trasplante (ya existe en el dataset)
# - Fecha_Egreso_Hospitalaria (ya existe en el dataset)
#
# Y casillas de apoyo:
# - "UCI_al_Momento_Tx" (Sí/No)
# - ¿Estuvo en UCI 6 meses pretrasplante? Sí/No → si Sí, “Número total de días en UCI pre-Tx”.
# - ¿Estuvo en UCI postrasplante? Sí/No → si Sí, “Número total de días en UCI post-Tx”.
# - ¿Estuvo en piso postrasplante? Sí/No → si Sí, “Número total de días en piso post-Tx”.
#
# No se preguntan fechas específicas de ingreso y alta en UCI o piso ya que los episodios de UCI y piso pueden ser múltiples y variados en el tiempo, pero con las fechas clave y las casillas de apoyo se puede calcular la duración total en cada fase.

# %% [markdown]
# Con esto, las variables de días que se pueden derivar son las siguientes:
# - Dias_Estancia_Hospitalaria: número de días transcurridos entre el ingreso hospitalario y el alta, incluyendo el periodo pre y postrasplante.
#   - variable calculada como: Fecha_Egreso_Hospitalaria - Fecha_Ingreso_Hospitalario
# - Días_Totales_Intrahosspitalarios_Pre_Tx: número de días desde la fecha de ingreso hospitalario hasta la fecha del trasplante.
#   - variable calculada como: Fecha_Trasplante - Fecha_Ingreso_Hospitalario
# - Días_En_UCI_Pre_Tx: días de estancia en UCI previos al trasplante en una ventana de 6 meses previos al trasplante.
# - Días_Totales_Intrahospitalarios_Post_Tx: número de días desde la fecha del trasplante hasta el alta hospitalaria.
#   - variable calculada como: Fecha_Egreso_Hospitalaria - Fecha_Trasplante
# - Días_En_UCI_Post_Tx: días de estancia en UCI posteriores al trasplante.
# - Días_En_Hospitalización_Piso_Post_Tx: días de hospitalización en piso posteriores al trasplante.

# %%
# Actualmente las variables de días que se encuentran son las siguientes:
days_vars = [
    "Antecedente_UCI_6_meses_PreOP",
    "Dias_Estancia_Hospitalaria",
    "Días_Hospitalización_UCI",
    "Días_Totales_Intrahospitalarios",
    "Días_En_Hospitalización_Piso",
    "Días_En_UCI_POP",
]
data[days_vars]
# Out:
#      Antecedente_UCI_6_meses_PreOP  Dias_Estancia_Hospitalaria  \
# 0                              0.0                          10
# 1                              0.0                           1
# 2                              0.0                          11
# 3                              0.0                           9
# 4                              0.0                           8
# ..                             ...                         ...
# 552                            0.0                           0
# 553                            1.0                           0
# 554                            0.0                           0
# 555                            0.0                           0
# 556                            0.0                           0
#
#      Días_Hospitalización_UCI  Días_Totales_Intrahospitalarios  \
# 0                         0.0                             10.0
# 1                         0.0                              1.0
# 2                         0.0                             13.0
# 3                         0.0                              9.0
# 4                         0.0                              7.0
# ..                        ...                              ...
# 552                       0.0                              NaN
# 553                       0.0                              NaN
# 554                       0.0                              NaN
# 555                       0.0                              NaN
# 556                       0.0                              NaN
#
#      Días_En_Hospitalización_Piso  Días_En_UCI_POP
# 0                             7.0              3.0
# 1                             0.0              1.0
# 2                             6.0              7.0
# 3                             4.0              5.0
# 4                             4.0              3.0
# ..                            ...              ...
# 552                           6.0              0.0
# 553                           NaN              NaN
# 554                           4.0              0.0
# 555                           9.0              0.0
# 556                          11.0              NaN
#
# [557 rows x 6 columns]

# %%
# Vamos a renombrar las variables de días para que queden más claras en cuanto a si son pre o post trasplante
dict_rename_days = {
    "Antecedente_UCI_6_meses_PreOP": "UCI_6_meses_Pre_Tx",
    "Días_Hospitalización_UCI": "Días_En_UCI_Pre_Tx",
    "Días_Totales_Intrahospitalarios": "Días_Totales_Intrahospitalarios_Post_Tx",
    "Días_En_Hospitalización_Piso": "Días_En_Hospitalización_Piso_Post_Tx",
    "Días_En_UCI_POP": "Días_En_UCI_Post_Tx",
}
data_new = data_new.rename(columns=dict_rename_days)

# renombramos también en el codebook, conservando las variables que no son de días
df_codebook["Variable"] = df_codebook["Variable"].map(lambda x: dict_rename_days.get(x, x))

# %%
# vamos a añadir la fecha de ingreso hospitalario
data_new['Fecha_Ingreso_Hospitalario'] = pd.NaT
# intentar estimar con la fecha de egreso hospitalario y los días de estancia hospitalaria
data_new.loc[
    data_new['Fecha_Egreso_Hospitalario'].notna() & data_new['Dias_Estancia_Hospitalaria'].notna(),
    'Fecha_Ingreso_Hospitalario' ] = data_new['Fecha_Egreso_Hospitalario'] - pd.to_timedelta(data_new['Dias_Estancia_Hospitalaria'], unit='D')

# np.nan if fecha ingeso es mayor a fecha trasplante
data_new.loc[
    data_new['Fecha_Ingreso_Hospitalario'] > data_new['Fecha_Tx'], 'Fecha_Ingreso_Hospitalario'] = pd.NaT


# Vamos a añadir las variables de días pre trasplante que faltan
data_new['Días_Totales_Intrahospitalarios_Pre_Tx'] = np.nan
# intentamos estimar con la fecha de ingreso hospitalario y la fecha de trasplante
data_new.loc[
    data_new['Fecha_Ingreso_Hospitalario'].notna() & data_new['Fecha_Tx'].notna(),
    'Días_Totales_Intrahospitalarios_Pre_Tx'] = (data_new['Fecha_Tx'] - data_new['Fecha_Ingreso_Hospitalario']).dt.days

# %% [markdown]
#  Días_Totales_Intrahospitalarios_Post_Tx

# %%
# vamos a intentar estimar los días de estancia en hospitalización post trasplante
dates_validation = data_new["Fecha_Egreso_Hospitalario"] - data_new["Fecha_Tx"]
calculated_values = data_new["Días_En_UCI_Post_Tx"] + data_new["Días_En_Hospitalización_Piso_Post_Tx"]
actual_values = data_new["Días_Totales_Intrahospitalarios_Post_Tx"]
check1 = calculated_values == actual_values

# donde dias totales de intrahospitalarios post tx es nulo y calculado no es nulo, lo llenamos
data_new.loc[actual_values.isna() & calculated_values.notna(), "Días_Totales_Intrahospitalarios_Post_Tx"] = calculated_values

# donde no hay fecha de egreso hospitalario, la estimamos con la suma de días en UCI y días en piso
data_new.loc[data_new["Fecha_Egreso_Hospitalario"].isna(), "Fecha_Egreso_Hospitalario"] = data_new["Fecha_Tx"] + pd.to_timedelta(calculated_values, unit='D')


# donde la fecha de egreso sea menor a la fecha de trasplante, la ponemos como nulo
data_new.loc[
    data_new["Fecha_Egreso_Hospitalario"] < data_new["Fecha_Tx"], "Fecha_Egreso_Hospitalario"] = pd.NaT

df_temp = pd.DataFrame({
    "dates validation": dates_validation.dt.days,
    "calculated_days": calculated_values,
    "actual_days": actual_values,
    "check 1": check1
})
df_temp
# Out:
#      dates validation  calculated_days  actual_days  check 1
# 0                 NaN             10.0         10.0     True
# 1                 NaN              1.0          1.0     True
# 2                 NaN             13.0         13.0     True
# 3                 NaN              9.0          9.0     True
# 4                 NaN              7.0          7.0     True
# ..                ...              ...          ...      ...
# 552               6.0              6.0          6.0    False
# 553               NaN              NaN          NaN    False
# 554               4.0              4.0          4.0    False
# 555               9.0              9.0          9.0    False
# 556              16.0              NaN          NaN    False
#
# [557 rows x 4 columns]

# %% [markdown]
# Adicionlmente, se preguntará la fecha de control/muerte para calcular la sobrevida en días, meses y años desde la fecha del trasplante.
# Está variable ya existe en el dataset original.
# Se conservará tal cual como está.

# %%
orden = ["Código anonimizado", "#Paciente_Tx", "Etiología_#1", "Etiología_#2", "Edad", "Sexo",	
         "Child_Pugh_Score_Cat", "Child_Pugh_Score", "Meld_Score","Diabetes_Mellitus","Tabaquismo","Alcoholismo",
        "Hipertensión_Arterial", "Peso_previo_Cx",	"Talla", "IMC", "Año_Tx", "Fecha_Tx", 'Fecha_Ingreso_Hospitalario', 'Días_Totales_Intrahospitalarios_Pre_Tx', "UCI_6_meses_Pre_Tx",  "Días_En_UCI_Pre_Tx", "UCI_al_Momento_Tx",	
        "Tiempo_Isquemia_Fria",	"Tiempo_Isquemia_caliente",	"Tiempo_Cx", "Tipo_Reconstrucción_Biliar",	
        "Infección_Al_Momento_Tx",	"Localización de la infección",	"Germen/Microorganismo aislado",	
        "Antibiotico_previo_al_Tx",	"Días_Tratamiento_Antibiótico_Previo_A_Tx#1",	
        "Antibiótico_Profiláctico_VS_Terapéutico",	"Antibiótico_1__Tx#1",	"Antibiótico_2_Tx#1",	
        "Antibiótico_3_Tx#1", "Antifúngico_Tx#1",	"Tiempo_De_Dosis_Hasta_Tx#1",	
        "Nutrición_Enteral","Días_Nutrición_Enteral",	"Complicaciones_Técnicas",	"Dias_Estancia_Hospitalaria",	
        "Días_En_UCI_Post_Tx", "Días_En_Hospitalización_Piso_Post_Tx",	"Días_Totales_Intrahospitalarios_Post_Tx",	
        "Inmunosupresión_con_Anticuerpos",	"Inmunosupresor_1_Postx",	"Inmunosupresor_2_PostTx",	
        "Inmunosupresor_1_1mesPostTx",	"Inmunosupresor_2_PostTx_1mesPx",	"Inmunosupresor_1_6mesesPostx",	
        "Inmunosupresor_2_6mesesPostTx", "Fecha_Egreso_UCI",	"Fecha_Egreso_Hospitalario",	
        "Requerimiento_de_diálisis","Trasfusión_GRE_hasta_1m_POP",	
        "Reintervención_Quirúrgica_hasta_1m_POP",	"Retrasplante",	
        "Vivo_Hoy",	"Fecha_Control/Muerte",	"SOBREVIDA_DIAS",	"SOBREVIDA_MESES",	"SOBREVIDA_AÑOS"]

# %%
data_new = data_new[orden]

# %%
# Se elimina está variable porque los valores se encuentran vacíos en su mayoria y no coincide con los días en UCI post trasplante
# por lo que se decide eliminarla
data_new = data_new.drop(columns=['Fecha_Egreso_UCI'])

# %% [markdown]
# Con data new se crea el excel que se subirá para crear la lista de sharepoint:
#
# En el se configurará para calcular las siguientes variables:
# - Dias_Estancia_Hospitalaria: Fecha_Egreso_Hospitalario - Fecha_Ingreso_Hospitalario
# - Días_Totales_Intrahospitalarios_Pre_Tx: Fecha_Tx - Fecha_Ingreso_Hospitalaria
# - Días_Totales_Intrahospitalarios_Post_Tx: Fecha_Egreso_Hospitalaria - Fecha_Tx
# - Sobrevida_Dias: Fecha_Control/Muerte - Fecha_Tx
# - Sobrevida_Meses: Sobrevida_Dias / 30
# - Sobrevida_Años: Sobrevida_Dias / 365
#
# El resto de variables se preguntarán directamente en el formulario de powerapps.

# %% [markdown]
# # Decodificación de categorías

# %% [markdown]
# Llenamos las variables númericas con -1.

# %%
numeric_vars = data_new.select_dtypes(include=['int64', 'float64']).columns
data_new[numeric_vars] = data_new[numeric_vars].fillna(-1)

# %% [markdown]
# Extraemos las variables categóricas y creamos un diccionario para decodificarlas usando el codebook.

# %%
df_categoricas = df_codebook[df_codebook['Tipo de Variable']=='Categórica']
mapping_dict = dict(zip(df_categoricas['Variable'], df_categoricas['Valores']))
mapping_dict
# Out:
# {'Etiología_#1': {'0': 'NINGUNA',
#   '1': 'HCV',
#   '2': 'HBV',
#   '3': 'NASH',
#   '4': 'ALCOHÓLICA',
#   '5': 'HEMOCROMATOSIS',
#   '6': 'DEF ALFA 1 ANTITRIPSINA',
#   '7': 'WILSON',
#   '8': 'HEPATITIS AUTOINMNE',
#   '9': 'COLANGITIS BILIAR PRIMARIA',
#   '10': 'COLANGITIS ESCLEROSANTE PRIMARIA',
#   '11': 'OVERLAP (CBP + AIH)',
#   '12': 'CRIPTOGENICA',
#   '13': 'FIBROSIS HEPATICA CONGENITA',
#   '14': 'ATRESIA VIAS BILIARES',
#   '15': 'COLANGIOCARCINOMA',
#   '16': 'TUMOR MIOFIBROBLASTICO',
#   '17': 'HEPATOBLASTOMA',
#   '18': 'ADENOMA GIGANTE',
#   '19': 'HIPERPLASIA NODULAR PROLIFERATIVA',
#   '20': 'ENFERMEDAD POLIQUISTICA',
#   '21': 'BUDDCHIARI',
#   '22': 'CIRROSIS BILIAR SECUNDARIA',
#   '23': 'FHF',
#   '24': 'HELLP',
#   '25': 'CIRROSIS DEL INJERTO',
#   '26': 'CIRROSIS DEL INJERTO',
#   '27': 'CIRROSIS HEPATICA POR COLANGIOPATÍA AUTOINMUNE'},
#  'Etiología_#2': {'0': 'NINGUNA',
#   '1': 'HCV',
#   '2': 'HBV',
#   '3': 'NASH',
#   '4': 'ALCOHÓLICA',
#   '5': 'HEMOCROMATOSIS',
#   '6': 'DEF ALFA 1 ANTITRIPSINA',
#   '7': 'WILSON',
#   '8': 'HEPATITIS AUTOINMNE',
#   '9': 'COLANGITIS BILIAR PRIMARIA',
#   '10': 'COLANGITIS ESCLEROSANTE PRIMARIA',
#   '11': 'OVERLAP (CBP + AIH)',
#   '12': 'CRIPTOGENICA',
#   '13': 'FIBROSIS HEPATICA CONGENITA',
#   '14': 'ATRESIA VIAS BILIARES',
#   '15': 'COLANGIOCARCINOMA',
#   '16': 'TUMOR MIOFIBROBLASTICO',
#   '17': 'HEPATOBLASTOMA',
#   '18': 'ADENOMA GIGANTE',
#   '19': 'HIPERPLASIA NODULAR PROLIFERATIVA',
#   '20': 'ENFERMEDAD POLIQUISTICA',
#   '21': 'BUDDCHIARI',
#   '22': 'CIRROSIS BILIAR SECUNDARIA ',
#   '23': 'FHF',
#   '24': 'SD DE HELLP',
#   '25': 'CIRROSIS DEL INJERTO',
#   '26': 'CIRROSIS DEL INJERTO',
#   '27': 'CIRROSIS HEPATICA POR COLANGIOPATÍA AUTOINMUNE'},
#  'Sexo': {'1': 'M', '2': 'F'},
#  'Diabetes_Mellitus': {'0': 'NO', '1': 'SI'},
#  'Tabaquismo': {'0': 'NO', '1': 'SI'},
#  'Alcoholismo': {'0': 'NO', '1': 'SI'},
#  'Hipertensión_Arterial': {'0': 'NO', '1': 'SI'},
#  'UCI_6_meses_Pre_Tx': {'0': 'NO', '1': 'SI'},
#  'UCI_al_Momento_Tx': {'0': 'NO', '1': 'SI'},
#  'Tipo_Reconstrucción_Biliar': {'1': 'Ducto - Ducto',
#   '2': 'Hepatico o Coledocoyeyunostomía + Reconstrucción en Y de Roux'},
#  'Infección_Al_Momento_Tx': {'0': 'NO', '1': 'SI'},
#  'Localización de la infección': {'1': 'Bacteremia primaria ',
#   '2': 'Neumonia ',
#   '3': 'IVU ',
#   '4': 'Bacteremia asociada a catéter ',
#   '5': 'Infección intraabdominal '},
#  'Germen/Microorganismo aislado': {'0': 'Escherichia coli',
#   '1': 'Klebsiella pneumoniae ss. pneumoniae',
#   '2': 'Staphylococcus aureus ss. aureus',
#   '3': 'Candida albicans',
#   '4': 'Enterococcus faecalis',
#   '5': 'Pseudomonas aeruginosa',
#   '6': 'Staphylococcus epidermidis',
#   '7': 'Candida glabrata',
#   '8': 'Enterococcus faecium',
#   '9': 'Enterobacter cloacae',
#   '10': 'Proteus mirabilis',
#   '11': 'Staphylococcus hominis ss. hominis',
#   '12': 'Candida parapsilosis',
#   '13': 'Citrobacter freundii',
#   '14': 'Staphylococcus haemolyticus',
#   '15': 'Morganella morganii ss. morganii',
#   '16': 'Klebsiella oxytoca',
#   '17': 'Klebsiella aerogenes',
#   '18': 'Candida tropicalis',
#   '19': 'Stenotrophomonas maltophilia',
#   '20': 'Enterobacter asburiae',
#   '21': 'Acinetobacter calcoaceticus-baumannii complex',
#   '22': 'Streptococcus agalactiae',
#   '23': 'Enterococcus gallinarum',
#   '24': 'Enterococcus durans',
#   '25': 'Enterobacter sp.',
#   '26': 'Candida kefyr (pseudotropicalis)',
#   '27': 'Acinetobacter baumannii',
#   '28': 'Pseudomonas putida',
#   '29': 'Enterococcus avium',
#   '30': 'Serratia marcescens',
#   '31': 'Citrobacter amalonaticus',
#   '32': 'Streptococcus salivarius',
#   '33': 'Streptococcus mitis',
#   '34': 'Candida sp.',
#   '35': 'Staphylococcus warneri',
#   '36': 'Staphylococcus capitis ss. capitis',
#   '37': 'Streptococcus pneumoniae',
#   '38': 'Moraxella (Branh.) catarrhalis',
#   '39': 'Salmonella sp.',
#   '40': 'Staphylococcus lugdunensis',
#   '41': 'Streptococcus, beta-haem. Group B',
#   '42': 'Raoultella planticola',
#   '43': 'Klebsiella pneumoniae ss. ozaenae',
#   '44': 'Saccharomyces cerevisiae',
#   '45': 'Pseudomonas fluorescens',
#   '46': 'Hafnia alvei',
#   '47': 'Gemella morbillorum',
#   '48': 'Enterococcus casseliflavus',
#   '49': 'Citrobacter koseri (diversus)',
#   '50': 'Haemophilus influenzae',
#   '51': 'Streptococcus constellatus',
#   '52': 'Candida krusei',
#   '53': 'Erysipelothrix rhusiopathiae',
#   '54': 'Chryseomonas luteola',
#   '55': 'Pantoea agglomerans',
#   '56': 'Candida famata',
#   '57': 'Streptococcus sanguinis I',
#   '58': 'Acinetobacter lwoffii',
#   '59': 'Streptococcus intermedius',
#   '60': 'Staphylococcus intermedius',
#   '61': 'Providencia rettgeri',
#   '62': 'Candida intermedia',
#   '63': 'Streptococcus parasanguinis',
#   '64': 'Gemella sp.',
#   '65': 'Candida lusitaniae',
#   '66': 'Klebsiella sp.',
#   '67': 'Cutibacterium acnes',
#   '68': 'Enterococcus raffinosus',
#   '69': 'Enterococcus sp.',
#   '70': 'Lactobacillus sp.',
#   '71': 'Leifsonia aquatica'},
#  'Antibiotico_previo_al_Tx': {'0': 'NO', '1': 'SI'},
#  'Antibiótico_Profiláctico_VS_Terapéutico': {'0': 'Profiláctico',
#   '1': 'Terapéutico '},
#  'Antibiótico_1__Tx#1': {'0': 'NO',
#   '1': 'CEFAZOLINA',
#   '2': 'CEFUROXIMA',
#   '3': 'CEFTRIAXONA',
#   '4': 'CEFEPIME',
#   '5': 'AMPICILINA SULBACTAM ',
#   '6': 'PIPERACILINA TAZOBACTAM ',
#   '7': 'CEFTAZIDIMA AVIBACTAM',
#   '8': 'MEROPENEM ',
#   '9': 'ERTAPENEM ',
#   '10': 'GENTAMICINA',
#   '11': 'AMIKACINA',
#   '12': 'CIPROFLOXACINA',
#   '13': 'CLINDAMICINA',
#   '14': 'VANCOMICINA',
#   '15': 'LINEZOLID',
#   '16': 'TIGECICLINA',
#   '17': 'METRONIDAZOL',
#   '18': 'TRIMETROPIM/SULFAMETOXAZOL'},
#  'Antibiótico_2_Tx#1': {'0': 'NO',
#   '1': 'CEFAZOLINA',
#   '2': 'CEFUROXIMA',
#   '3': 'CEFTRIAXONA',
#   '4': 'CEFEPIME',
#   '5': 'AMPICILINA SULBACTAM ',
#   '6': 'PIPERACILINA TAZOBACTAM ',
#   '7': 'CEFTAZIDIMA AVIBACTAM',
#   '8': 'MEROPENEM ',
#   '9': 'ERTAPENEM ',
#   '10': 'GENTAMICINA',
#   '11': 'AMIKACINA',
#   '12': 'CIPROFLOXACINA',
#   '13': 'CLINDAMICINA',
#   '14': 'VANCOMICINA',
#   '15': 'LINEZOLID',
#   '16': 'TIGECICLINA',
#   '17': 'METRONIDAZOL',
#   '18': 'TRIMETROPIM/SULFAMETOXAZOL',
#   '19': 'DAPTOMICINA',
#   '20': 'AZTREONAM'},
#  'Antibiótico_3_Tx#1': {'0': 'NO',
#   '1': 'CEFAZOLINA',
#   '2': 'CEFUROXIMA',
#   '3': 'CEFTRIAXONA',
#   '4': 'CEFEPIME',
#   '5': 'AMPICILINA SULBACTAM ',
#   '6': 'PIPERACILINA TAZOBACTAM ',
#   '7': 'CEFTAZIDIMA AVIBACTAM',
#   '8': 'MEROPENEM ',
#   '9': 'ERTAPENEM ',
#   '10': 'GENTAMICINA',
#   '11': 'AMIKACINA',
#   '12': 'CIPROFLOXACINA',
#   '13': 'CLINDAMICINA',
#   '14': 'VANCOMICINA',
#   '15': 'LINEZOLID',
#   '16': 'TIGECICLINA',
#   '17': 'METRONIDAZOL',
#   '18': 'TRIMETROPIM/SULFAMETOXAZOL'},
#  'Antifúngico_Tx#1': {'0': 'NO', '1': 'FLUCONAZOL ', '2': 'VORICONAZOL'},
#  'Inmunosupresión_con_Anticuerpos': {'0': 'No',
#   '1': 'SIMULECT (BASILIXIMAB)',
#   '2': 'ZENAPAX (DACLIZUMAB)',
#   '3': 'OKT3 (ORTHOCLONE)',
#   '4': 'TIMOGLOBULINA'},
#  'Inmunosupresor_1_Postx': {'0': 'No',
#   '1': 'CICLOSPORINA',
#   '2': 'TACROLIMUS',
#   '3': 'SIROLIMUS'},
#  'Inmunosupresor_2_PostTx': {'0': 'No',
#   '1': 'MICOFENOLATO',
#   '2': 'AZATIOPRINA'},
#  'Inmunosupresor_1_1mesPostTx': {'0': 'No',
#   '1': 'CICLOSPORINA',
#   '2': 'TACROLIMUS',
#   '3': 'SIROLIMUS'},
#  'Inmunosupresor_2_PostTx_1mesPx': {'0': 'No',
#   '1': 'MICOFENOLATO',
#   '2': 'AZATIOPRINA'},
#  'Inmunosupresor_1_6mesesPostx': {'0': 'No',
#   '1': 'CICLOSPORINA',
#   '2': 'TACROLIMUS',
#   '3': 'SIROLIMUS'},
#  'Inmunosupresor_2_6mesesPostTx': {'0': 'No',
#   '1': 'MICOFENOLATO',
#   '2': 'AZATIOPRINA'},
#  'Requerimiento_de_diálisis': {'0': 'NO', '1': 'SI'},
#  'Trasfusión_GRE_hasta_1m_POP': {'0': 'NO', '1': 'SI'},
#  'Reintervención_Quirúrgica_hasta_1m_POP': {'0': 'NO', '1': 'SI'},
#  'Retrasplante': {'0': 'NO', '1': 'SI'},
#  'Vivo_Hoy': {'0': 'NO', '1': 'SI'}}

# %% [markdown]
# Mapeamos los codigos a las categorías correspondientes y llenamos con "DESCONOCIDO" los valores que no se encuentren en el diccionario.

# %%
def map_values(column):
    if column.name in mapping_dict:
        mapping = mapping_dict.get(column.name)
        if pd.isna(mapping):
            return column
        column_mapped = column.map(lambda x: mapping.get(str(int(x)), x) if pd.notna(x) and str(int(x)) in mapping else x).replace(-1.0, "DESCONOCIDO")
        return column_mapped
    return column
data_mapped = data_new.apply(map_values)
data_mapped
# Out:
#     Código anonimizado  #Paciente_Tx  \
# 0                 P001             1
# 1                 P002             2
# 2                 P003             3
# 3                 P004             4
# 4                 P005             5
# ..                 ...           ...
# 552               P553           553
# 553               P554           554
# 554               P555           555
# 555               P556           556
# 556               P557           557
#
#                                        Etiología_#1 Etiología_#2  Edad Sexo  \
# 0                                               HCV      NINGUNA    62    M
# 1                                              NASH      NINGUNA    62    M
# 2                               HEPATITIS AUTOINMNE      NINGUNA    56    F
# 3                                              NASH      NINGUNA    58    M
# 4                                        ALCOHÓLICA      NINGUNA    62    F
# ..                                              ...          ...   ...  ...
# 552                                    CRIPTOGENICA      NINGUNA    22    M
# 553                             HEPATITIS AUTOINMNE      NINGUNA    33    F
# 554                                            NASH   ALCOHÓLICA    55    M
# 555  CIRROSIS HEPATICA POR COLANGIOPATÍA AUTOINMUNE      NINGUNA    54    F
# 556                                      ALCOHÓLICA      NINGUNA    63    M
#
#     Child_Pugh_Score_Cat  Child_Pugh_Score  Meld_Score Diabetes_Mellitus  ...  \
# 0                    NaN              -1.0        18.0                NO  ...
# 1                    NaN              -1.0        17.0                NO  ...
# 2                    NaN              -1.0        15.0                NO  ...
# 3                    NaN              -1.0         9.0                NO  ...
# 4                    NaN              -1.0        22.0                SI  ...
# ..                   ...               ...         ...               ...  ...
# 552                    C              11.0        22.0                NO  ...
# 553                    C              10.0        21.0                NO  ...
# 554                    B               9.0        20.0                SI  ...
# 555                    B               9.0        14.0                NO  ...
# 556                    B               9.0        18.0                NO  ...
#
#     Fecha_Egreso_Hospitalario Requerimiento_de_diálisis  \
# 0                  2009-01-13                        NO
# 1                  2009-01-11                        NO
# 2                  2009-02-16                        NO
# 3                  2009-02-14                        NO
# 4                  2009-02-18                        NO
# ..                        ...                       ...
# 552                2024-09-27                        NO
# 553                       NaT                        SI
# 554                2024-10-12                        NO
# 555                2024-10-25                        NO
# 556                2024-11-14                        NO
#
#     Trasfusión_GRE_hasta_1m_POP  Reintervención_Quirúrgica_hasta_1m_POP  \
# 0                            NO                                      SI
# 1                            NO                                      SI
# 2                            NO                                      NO
# 3                            NO                                      NO
# 4                            NO                                      NO
# ..                          ...                                     ...
# 552                          NO                                      NO
# 553                          SI                             DESCONOCIDO
# 554                          NO                                      NO
# 555                          NO                                      NO
# 556                          NO                                      SI
#
#      Retrasplante  Vivo_Hoy  Fecha_Control/Muerte SOBREVIDA_DIAS  \
# 0              NO        NO            2009-10-05            275
# 1              NO        NO            2009-01-11              1
# 2              NO        SI            2023-12-31           5444
# 3              NO        SI            2023-12-31           5442
# 4              NO        SI            2023-12-31           4724
# ..            ...       ...                   ...            ...
# 552            NO        SI            2024-09-21              0
# 553   DESCONOCIDO        NO            2025-03-31            174
# 554            NO        SI            2025-05-07            203
# 555            NO        SI            2025-05-13            196
# 556            NO        SI            2025-05-13          45772
#
#     SOBREVIDA_MESES  SOBREVIDA_AÑOS
# 0              9.17            0.76
# 1              0.03            0.00
# 2            181.47           15.12
# 3            181.40           15.12
# 4            157.47           13.12
# ..              ...             ...
# 552            0.00            0.00
# 553            5.00            0.00
# 554            6.00            0.00
# 555            6.00            0.00
# 556         1503.00          125.00
#
# [557 rows x 62 columns]

# %% [markdown]
# Guardamos el nuevo dataset como un archivo excel para subir al sharepoint.

# %%
data_mapped.to_excel('../data/Base_infecciones_POPTH_nuevo_modelado.xlsx', index=False)
